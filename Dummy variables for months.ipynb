# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm

# %%
df = pd.read_excel('/Users/Suwani/Desktop/Moodys Project/2018_2019.xlsx', sheet_name = 'Sheet4')

# %%
#df = pd.read_excel('/Users/Suwani/Desktop/Moodys Project/ALL_AGG_2018.xlsx', sheet_name = 'Sheet3')

# %%
df.head()
# Out:
#    Year    Month  T  Day WorkingD  MEAN_comp  AGG_MEAN_comp  AGG_Positive  \
# 0  2018  January  1    2        W   0.178558       0.153070            28
# 1  2018  January  2    3        W   0.032490       0.032490            25
# 2  2018  January  3    4        W   0.147393       0.147393            25
# 3  2018  January  4    5        W   0.119964       0.119964            38
# 4  2018  January  5    8        W   0.229926       0.097353            40
#
#    Unnamed: 8    Price     Open     High      Low     Vol.  Change        Date
# 0         NaN  6411.27  6368.05  6431.16  6367.95    5.20M    0.66  2018-01-02
# 1         NaN  6463.50  6420.72  6465.62  6411.27   13.37M    0.81  2018-01-03
# 2         NaN  6459.66  6465.37  6469.38  6430.63   14.31M   -0.06  2018-01-04
# 3         NaN  6514.73  6462.85  6520.80  6459.66   20.24M    0.85  2018-01-05
# 4         NaN  6540.51  6513.55  6545.16  6513.55  112.09M    0.40  2018-01-08

# %%
from statsmodels.formula.api import ols
fit = ols('Change ~ AGG_MEAN_comp', data=df).fit()

# %%
fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Change   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.9390
# Date:                Wed, 05 Feb 2020   Prob (F-statistic):              0.333
# Time:                        17:54:14   Log-Likelihood:                -318.09
# No. Observations:                 438   AIC:                             640.2
# Df Residuals:                     436   BIC:                             648.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
fit1 = ols('Change ~ C(Month) + AGG_MEAN_comp + T', data = df).fit()

# %%
fit1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Change   R-squared:                       0.044
# Model:                            OLS   Adj. R-squared:                 -0.012
# Method:                 Least Squares   F-statistic:                    0.7910
# Date:                Fri, 03 Jan 2020   Prob (F-statistic):              0.669
# Time:                        11:15:03   Log-Likelihood:                -140.61
# No. Observations:                 239   AIC:                             309.2
# Df Residuals:                     225   BIC:                             357.9
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# ...

# %%
df1 = pd.read_excel('/Users/Suwani/Desktop/Moodys Project/2018_2019.xlsx', sheet_name = 'Sheet4')

# %%
df1.head()
# Out:
#    Year    Month  T  Day WorkingD  MEAN_comp  AGG_MEAN_comp  AGG_Positive  \
# 0  2018  January  1    2        W   0.178558       0.153070            28
# 1  2018  January  2    3        W   0.032490       0.032490            25
# 2  2018  January  3    4        W   0.147393       0.147393            25
# 3  2018  January  4    5        W   0.119964       0.119964            38
# 4  2018  January  5    8        W   0.229926       0.097353            40
#
#    Unnamed: 8    Price     Open     High      Low     Vol.  Change        Date
# 0         NaN  6411.27  6368.05  6431.16  6367.95    5.20M    0.66  2018-01-02
# 1         NaN  6463.50  6420.72  6465.62  6411.27   13.37M    0.81  2018-01-03
# 2         NaN  6459.66  6465.37  6469.38  6430.63   14.31M   -0.06  2018-01-04
# 3         NaN  6514.73  6462.85  6520.80  6459.66   20.24M    0.85  2018-01-05
# 4         NaN  6540.51  6513.55  6545.16  6513.55  112.09M    0.40  2018-01-08

# %%
from statsmodels.formula.api import ols
fit = ols('Change ~ C(Month) + C(Year) + AGG_MEAN_comp + T', data=df1).fit() 
fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Change   R-squared:                       0.052
# Model:                            OLS   Adj. R-squared:                  0.020
# Method:                 Least Squares   F-statistic:                     1.643
# Date:                Fri, 03 Jan 2020   Prob (F-statistic):             0.0650
# Time:                        22:47:30   Log-Likelihood:                -306.97
# No. Observations:                 438   AIC:                             643.9
# Df Residuals:                     423   BIC:                             705.2
# Df Model:                          14
# Covariance Type:            nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# ...
