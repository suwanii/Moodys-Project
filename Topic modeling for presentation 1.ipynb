# %%
#https://stackabuse.com/python-for-nlp-topic-modeling/

# %% [markdown]
# ## Latent Dirichlet Allocation (LDA) algorithm

# %%
import pandas as pd
import numpy as np

reviews_datasets = pd.read_excel('/Users/Suwani/Desktop/Moodys Project/Cleaned data/2019/sep19_cleaned.xlsx')
reviews_datasets.dropna()
# Out:
#       Unnamed: 0                                           Headline  \
# 0              0  “Sri Lanka is running out of time to agree on ...
# 1              1              A 4th coal power plant for Sri Lanka?
# 2              2  Sri Lanka’s UN delegation meets with Under Sec...
# 3              3  Sri Lanka welcomes proposal for Maldives’ re-a...
# 4              4  Sri Lanka celebrates World Tourism Day 2019 wi...
# 5              5  Sri Lanka arrives in Karachi for SL vs Pak series
# 6              6  Yoshitha Rajapaksa reinstated as Lieutenant of...
# 7              7  PM admits his involvement in the collapse of S...
# 8              8  Sri Lanka Administrative Service Association t...
# 9              9  Sisu Dham Sewana will help Buddhism flourish i...
# 10            10  I will uplift the education system in Sri Lank...
# 11            11  Sri Lanka has lowest maternal mortality rate i...
# 12            12  Sri Lanka has the lowest maternal mortality ra...
# 13            13  Admiral Wasantha Karannagoda to become first S...
# 14            14  Moody’s issues a warning on Sri Lanka’s debt s...
# 15            15  Global warming will result in a loss of income...
# 16            16  46th ARTDO International Conference to be held...
# 17            17  Malaria raising its head in Sri Lanka once again?
# 18            18  Sri Lanka to issue Yen denominated Samurai Bon...
# 19            19  Sri Lanka to be recognized for eradicating mat...
# 20            20  Forget our differences for a greater Sri Lanka...
# 21            21  Sri Lanka’s rupee closed at its lowest level i...
# 22            22  Annual congregation of Dawoodi Bohra Community...
# 23            23  Sri Lankan group enters the finalist list of M...
# 24            24  “Sri Lankan economy is on the brink of a disas...
# 25            25  Sri Lanka Export Development act debated in pa...
# 26            26                    Sri Lanka is measles free : WHO
# 27            27  Nigeria to look into closure of their embassy ...
# 28            28  Six US personnel in Sri Lanka, refuses to allo...
# 29            29  Prime Minister Ranil Wickremesinghe returns to...
# ...          ...                                                ...
# 1105        1105  China's ALIT rejects Sri Lanka leader's graft ...
# 1106        1106  Australia says asylum seekers from Sri Lanka r...
# 1107        1107  Sri Lanka presidential nominee Rajapaksa would...
# 1108        1108  Opening of Sri Lanka's tallest tower marred by...
# 1109        1109  Sri Lanka presidential frontrunner loses bid t...
# 1110        1110  Sri Lanka tourist arrivals fall for 5th month ...
# 1111        1111  In Sri Lanka, a polarizing politician reaches ...
# 1112        1112  Sri Lanka seeks extradition of ex-central bank...
# 1113        1113  Sri Lanka rupee weakens amid fund outflows; st...
# 1114        1114  Sri Lanka's ruling party nominates deputy lead...
# 1115        1115  UPDATE 1-Sri Lanka presidential nominee Rajapa...
# 1116        1116  Exclusive: Sri Lanka to overshoot 2019 fiscal ...
# 1117        1117  Sri Lanka rupee weakens to over 7-month closin...
# 1118        1118  Sri Lankan presidential nominee Rajapaksa face...
# 1119        1119  Sri Lankan lawmakers to investigate Lotus Towe...
# 1120        1120  Sri Lankan rupee strengthens for second day; s...
# 1121        1121  U.N. suspends Sri Lankan troops from peacekeep...
# 1122        1122  Sri Lankan rupee ends at its lowest in over 7 ...
# 1123        1123  Sri Lankan rupee recovers from 7-month closing...
appear in less than 80% of the document and appear in at least 2 documents. '''

#Creating a vocabulary for all the words in the dataset and removing stop words
from sklearn.feature_extraction.text import CountVectorizer

count_vect = CountVectorizer(max_df=0.8, min_df=2, stop_words=stopwords)
doc_term_matrix = count_vect.fit_transform(reviews_datasets['Headline'].values.astype('U'))

# %%
doc_term_matrix
# Out:
# <1135x1163 sparse matrix of type '<class 'numpy.int64'>'
# 	with 4507 stored elements in Compressed Sparse Row format>

# %%
#n_components specifies the number of categories


from sklearn.decomposition import LatentDirichletAllocation

LDA = LatentDirichletAllocation(n_components=5, random_state=42)
LDA.fit(doc_term_matrix)
# Out:
# LatentDirichletAllocation(batch_size=128, doc_topic_prior=None,
#                           evaluate_every=-1, learning_decay=0.7,
#                           learning_method='batch', learning_offset=10.0,
#                           max_doc_update_iter=100, max_iter=10,
#                           mean_change_tol=0.001, n_components=5, n_jobs=None,
#                           perp_tol=0.1, random_state=42, topic_word_prior=None,
#                           total_samples=1000000.0, verbose=0)

# %%
#fetches 10 words from our vocabulary:
import random

for i in range(10):
    random_id = random.randint(0,len(count_vect.get_feature_names()))
    print(count_vect.get_feature_names()[random_id])
# Out:
# progress
# house
# bestowed
# complexes
# almost
# expressway
# tea
# railways
# summit
# beedi

# %%
#get the first topic
first_topic = LDA.components_[0]

# %%
#10 words with the highest probabilities will now belong to the last 10 indexes of the array
top_topic_words = first_topic.argsort()[-10:]

# %%
top_topic_words
# Out:
# array([ 661,  912,  162, 1069,  714,   99, 1004, 1058, 1009,  818])

# %%
for i in top_topic_words:
    print(count_vect.get_feature_names()[i])
# Out:
# management
# school
# business
# tower
# national
# awards
# state
# today
# strike
# president

# %%
for i,topic in enumerate(LDA.components_):
    print(f'Top 10 words for topic #{i}:')
    print([count_vect.get_feature_names()[i] for i in topic.argsort()[-10:]])
    print('\n')
# Out:
# Top 10 words for topic #0:
# ['management', 'school', 'business', 'tower', 'national', 'awards', 'state', 'today', 'strike', 'president']
#
#
# Top 10 words for topic #1:
# ['host', 'two', 'group', 'srilankan', 'wins', 'asia', 'opens', 'airlines', 'trade', 'indian']
#
#
# Top 10 words for topic #2:
# ['country', 'bank', 'sajith', 'minister', 'new', 'india', 'president', 'pm', 'cricket', 'pakistan']
#
#
# Top 10 words for topic #3:
# ['asia', 'wins', 'launches', 'presidential', '2019', 'slfp', 'candidate', 'series', 'world', 'first']
#
#
# Top 10 words for topic #4:
# ['top', 'support', 'presidential', '2019', 'new', 'award', 'year', 'wins', 'colombo', 'awards']

# %%
topic_values = LDA.transform(doc_term_matrix)
topic_values.shape
# Out:
# (1135, 5)

# %%
reviews_datasets['Topic'] = topic_values.argmax(axis=1)

# %%
reviews_datasets.head()
# Out:
#    Unnamed: 0                                           Headline        Date  \
# 0           0  “Sri Lanka is running out of time to agree on ...  2019-09-29
# 1           1              A 4th coal power plant for Sri Lanka?  2019-09-29
# 2           2  Sri Lanka’s UN delegation meets with Under Sec...  2019-09-28
# 3           3  Sri Lanka welcomes proposal for Maldives’ re-a...  2019-09-28
# 4           4  Sri Lanka celebrates World Tourism Day 2019 wi...  2019-09-27
#
#    Year  Month  Day  Topic
# 0  2019      9   29      4
# 1  2019      9   29      2
# 2  2019      9   28      0
# 3  2019      9   28      1
# 4  2019      9   27      3
